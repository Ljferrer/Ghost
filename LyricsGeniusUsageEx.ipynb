# %%
import lyricsgenius as lg

g = lg.Genius('ut57Uj2hNnGPODi_8nSAfego-6AHhWgVCFmlSps0LGhI1uAyqFKx1b8HQM-KDQW_')
g.excluded_terms = ['(Remix)', '(Live)', '(Translation)']

# %%
bbel = g.search_artist('Billie Eilish')
# Out:
# Searching for songs by Billie Eilish...
#
# Song 1: "​when the party's over"
# Song 2: "​bury a friend"
# Song 3: "​idontwannabeyouanymore"
# Song 4: "​bad guy"
# Song 5: "​wish you were gay"
# Song 6: "​you should see me in a crown"
# Song 7: "​bellyache"
# Song 8: "​​ocean eyes"
# Song 9: "COPYCAT"
# Song 10: "​i love you"
# Song 11: "​watch"
# Song 12: "​my boy"
# Song 13: "Six Feet Under"
# Song 14: "​my strange addiction"
# Song 15: "​xanny"
# Song 16: "​hostage"
# Song 17: "​all the good girls go to hell"
# Song 18: "​​come out and play"
# Song 19: "​listen before i go"
# Song 20: "​ilomilo"
# Song 21: "​bitches broken hearts"
# Song 22: "​​party favor"
# Song 23: "8"
# Song 24: "​goodbye"
# Song 25: "Bored"
# "Ocean Eyes (Blackbear Remix)" is not valid. Skipping.
# Song 26: "WHEN I WAS OLDER"
# "Ocean Eyes (Astronomyy Remix)" is not valid. Skipping.
# Song 27: "6.18.18"
# Song 28: "!!!!!!!"
# Song 29: "Fingers Crossed"
# Song 30: "​sHE's brOKen"
# Song 31: "​limbo*"
# ...

# %%
bbel.songs
# Out:
# [("\u200bwhen the party's over", 'Billie Eilish'),
#  ('\u200bbury a friend', 'Billie Eilish'),
#  ('\u200bidontwannabeyouanymore', 'Billie Eilish'),
#  ('\u200bbad guy', 'Billie Eilish'),
#  ('\u200bwish you were gay', 'Billie Eilish'),
#  ('\u200byou should see me in a crown', 'Billie Eilish'),
#  ('\u200bbellyache', 'Billie Eilish'),
#  ('\u200b\u200bocean eyes', 'Billie Eilish'),
#  ('COPYCAT', 'Billie Eilish'),
#  ('\u200bi love you', 'Billie Eilish'),
#  ('\u200bwatch', 'Billie Eilish'),
#  ('\u200bmy boy', 'Billie Eilish'),
#  ('Six Feet Under', 'Billie Eilish'),
#  ('\u200bmy strange addiction', 'Billie Eilish'),
#  ('\u200bxanny', 'Billie Eilish'),
#  ('\u200bhostage', 'Billie Eilish'),
#  ('\u200ball the good girls go to hell', 'Billie Eilish'),
#  ('\u200b\u200bcome out and play', 'Billie Eilish'),
#  ('\u200blisten before i go', 'Billie Eilish'),
#  ('\u200bilomilo', 'Billie Eilish'),
#  ('\u200bbitches broken hearts', 'Billie Eilish'),
# ...

# %%
bbel.lyrics = dict()

for song_name in bbel.songs:
    print(song_name.lyrics)
#     song = g.search_song(*song_name)
#     bbel.lyrics(song)
    break
# Out:
# [Verse 1]
# Don't you know I'm no good for you?
# I've learned to lose you, can't afford to
# Tore my shirt to stop you bleedin'
# But nothin' ever stops you leavin'
#
# [Chorus]
# Quiet when I'm coming home and I'm on my own
# I could lie, say I like it like that, like it like that
# I could lie, say I like it like that, like it like that
#
# [Verse 2]
# Don't you know too much already?
# I'll only hurt you if you let me
# Call me friend, but keep me closer (Call me back)
# And I'll call you when the party's over
#
# [Chorus]
# Quiet when I'm coming home and I'm on my own
# And I could lie, say I like it like that, like it like that
# Yeah, I could lie, say I like it like that, like it like that
#
# [Bridge]
# But nothin' is better sometimes
# Once we've both said our goodbyes
# Let's just let it go
# Let me let you go
#
# [Chorus]
# Quiet when I'm coming home and I'm on my own
# I could lie, say I like it like that, like it like that
# ...
